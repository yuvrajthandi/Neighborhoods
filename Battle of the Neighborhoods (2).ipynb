# %% [markdown]
# # STARBUCKS
# ### Yankees Stadium: Bronx, NY United States

# %% [markdown]
# ###### Import Packages

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

# import json
import json

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ###### Credentials

# %%
CLIENT_ID = '33WRHSWEWLHEFCRKNOYEQNGLDCXYDFE0TC5INIV1U2YEHCJZ' # Foursquare ID
CLIENT_SECRET = 'MDAEQMKMQABCPLKLO1J4PQXRW4YREC2SPTFRYTUTEUZ4Y1DJ' # Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 33WRHSWEWLHEFCRKNOYEQNGLDCXYDFE0TC5INIV1U2YEHCJZ
# CLIENT_SECRET:MDAEQMKMQABCPLKLO1J4PQXRW4YREC2SPTFRYTUTEUZ4Y1DJ

# %% [markdown]
# ###### Yankees Stadium

# %%
# establish location using geolocator
address = '1 E 161st St, Bronx, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.82958275 -73.926521184919

# %% [markdown]
# ###### Setting Query and Fetching Results

# %%
# set query to search for all Starbucks in the area
search_query = ('Starbucks')
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Starbucks .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=33WRHSWEWLHEFCRKNOYEQNGLDCXYDFE0TC5INIV1U2YEHCJZ&client_secret=MDAEQMKMQABCPLKLO1J4PQXRW4YREC2SPTFRYTUTEUZ4Y1DJ&ll=40.82958275,-73.926521184919&v=20180604&query=Starbucks&radius=2000&limit=30'

# %%
# fetch results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dac8c0ea4b51b002cb18a96'},
#  'response': {'venues': [{'id': '4b25a38bf964a520dc7424e3',
#     'name': 'Starbucks',
#     'location': {'address': '4001 Broadway',
#      'crossStreet': 'at W 168th St',
#      'lat': 40.84118767,
#      'lng': -73.9398428,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.84118767,
#        'lng': -73.9398428}],
#      'distance': 1711,
#      'postalCode': '10032',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4001 Broadway (at W 168th St)',
#       'New York, NY 10032',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571589134',
#     'hasPerk': False},
#    {'id': '4a25743af964a520547e1fe3',
#     'name': 'Starbucks',
#     'location': {'address': '301 W 145th St',
#      'crossStreet': 'at Bradhurst Ave',
#      'lat': 40.82327035,
#      'lng': -73.94283396,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.82327035,
#        'lng': -73.94283396}],
#      'distance': 1543,
#      'postalCode': '10039',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['301 W 145th St (at Bradhurst Ave)',
#       'New York, NY 10039',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571589134',
#     'hasPerk': False},
#    {'id': '4fc94580d4f24895b4467d5c',
#     'name': 'Starbucks',
#     'location': {'address': '700 Exterior St',
#      'crossStreet': 'at Target',
#      'lat': 40.81963,
#      'lng': -73.93039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.81963,
#        'lng': -73.93039}],
#      'distance': 1154,
#      'postalCode': '10451',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['700 Exterior St (at Target)',
#       'Bronx, NY 10451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571589134',
#     'hasPerk': False},
#    {'id': '55f96d71498e452a8e98af29',
#     'name': 'Starbucks',
#     'location': {'address': '260 E 161st St',
#      'crossStreet': 'at Morris Ave',
#      'lat': 40.82555649,
#      'lng': -73.91886538,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.82555649,
#        'lng': -73.91886538}],
#      'distance': 785,
#      'postalCode': '10451',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['260 E 161st St (at Morris Ave)',
#       'Bronx, NY 10451',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571589134',
#     'hasPerk': False},
#    {'id': '54636ccb498ec5113126882f',
#     'name': 'Starbucks @ BN Bookstore',
#     'location': {'address': '3954 Broadway',
#      'crossStreet': 'Columbia Medical Center',
#      'lat': 40.842929,
#      'lng': -73.942952,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.842929,
#        'lng': -73.942952}],
#      'distance': 2030,
#      'postalCode': '10032',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['3954 Broadway (Columbia Medical Center)',
#       'New York, NY 10032',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571589134',
#     'hasPerk': False},
#    {'id': '4d949586cf46224b5fe49794',
#     'name': 'Starbucks',
#     'location': {'address': 'CIty College of New York',
#      'crossStreet': 'at North Academic Center',
#      'lat': 40.81992301549787,
#      'lng': -73.9501539067642,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.81992301549787,
#        'lng': -73.9501539067642}],
#      'distance': 2262,
#      'postalCode': '10031',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['CIty College of New York (at North Academic Center)',
#       'New York, NY 10031',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571589134',
#     'hasPerk': False},
#    {'id': '5bca2e431ffe97002c40830a',
#     'name': 'Starbucks',
#     'location': {'address': '177 Fort Washington Ave',
#      'crossStreet': 'West 168th Street',
#      'lat': 40.841488,
#      'lng': -73.94276,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.841488,
#        'lng': -73.94276}],
#      'distance': 1904,
#      'postalCode': '10032',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['177 Fort Washington Ave (West 168th Street)',
#       'New York, NY 10032',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571589134',
#     'hasPerk': False},
#    {'id': '4c28ecbd360cef3b2a2ebedc',
#     'name': 'CCNY Starbucks',
#     'location': {'address': 'NAC Plaza / Marshak Science Building',
#      'crossStreet': 'at CCNY',
#      'lat': 40.823632880508285,
#      'lng': -73.94580106689695,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.823632880508285,
#        'lng': -73.94580106689695}],
#      'distance': 1753,
#      'postalCode': '10032',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['NAC Plaza / Marshak Science Building (at CCNY)',
#       'New York, NY 10032',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d115951735',
#       'name': 'Bike Shop',
#       'pluralName': 'Bike Shops',
#       'shortName': 'Bike Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571589134',
#     'hasPerk': False}]}}

# %% [markdown]
# ###### Gathering and Cleaning Data

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)


dataframe
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 5  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 6  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 7  [{'id': '4bf58dd8d48988d115951735', 'name': 'B...    False
#
#                          id                      location.address location.cc  \
# 0  4b25a38bf964a520dc7424e3                         4001 Broadway          US
# 1  4a25743af964a520547e1fe3                        301 W 145th St          US
# 2  4fc94580d4f24895b4467d5c                       700 Exterior St          US
# 3  55f96d71498e452a8e98af29                        260 E 161st St          US
# 4  54636ccb498ec5113126882f                         3954 Broadway          US
# 5  4d949586cf46224b5fe49794              CIty College of New York          US
# 6  5bca2e431ffe97002c40830a               177 Fort Washington Ave          US
# 7  4c28ecbd360cef3b2a2ebedc  NAC Plaza / Marshak Science Building          US
#
#   location.city location.country      location.crossStreet  location.distance  \
# 0      New York    United States             at W 168th St               1711
# 1      New York    United States          at Bradhurst Ave               1543
# 2         Bronx    United States                 at Target               1154
# 3         Bronx    United States             at Morris Ave                785
# 4      New York    United States   Columbia Medical Center               2030
# 5      New York    United States  at North Academic Center               2262
# 6      New York    United States         West 168th Street               1904
# 7      New York    United States                   at CCNY               1753
#
#                            location.formattedAddress  \
# 0  [4001 Broadway (at W 168th St), New York, NY 1...
# 1  [301 W 145th St (at Bradhurst Ave), New York, ...
# 2  [700 Exterior St (at Target), Bronx, NY 10451,...
# 3  [260 E 161st St (at Morris Ave), Bronx, NY 104...
# 4  [3954 Broadway (Columbia Medical Center), New ...
# 5  [CIty College of New York (at North Academic C...
# 6  [177 Fort Washington Ave (West 168th Street), ...
# 7  [NAC Plaza / Marshak Science Building (at CCNY...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.84118767, 'lng...     40.841188
# 1  [{'label': 'display', 'lat': 40.82327035, 'lng...     40.823270
# 2  [{'label': 'display', 'lat': 40.81963, 'lng': ...     40.819630
# 3  [{'label': 'display', 'lat': 40.82555649, 'lng...     40.825556
# 4  [{'label': 'display', 'lat': 40.842929, 'lng':...     40.842929
# 5  [{'label': 'display', 'lat': 40.81992301549787...     40.819923
# 6  [{'label': 'display', 'lat': 40.841488, 'lng':...     40.841488
# 7  [{'label': 'display', 'lat': 40.82363288050828...     40.823633
#
#    location.lng location.postalCode location.state                      name  \
# 0    -73.939843               10032             NY                 Starbucks
# 1    -73.942834               10039             NY                 Starbucks
# 2    -73.930390               10451             NY                 Starbucks
# 3    -73.918865               10451             NY                 Starbucks
# 4    -73.942952               10032             NY  Starbucks @ BN Bookstore
# 5    -73.950154               10031             NY                 Starbucks
# 6    -73.942760               10032             NY                 Starbucks
# 7    -73.945801               10032             NY            CCNY Starbucks
#
#      referralId
# 0  v-1571589134
# 1  v-1571589134
# 2  v-1571589134
# 3  v-1571589134
# 4  v-1571589134
# 5  v-1571589134
# 6  v-1571589134
# 7  v-1571589134

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                        name   categories  \
# 0                 Starbucks  Coffee Shop
# 1                 Starbucks  Coffee Shop
# 2                 Starbucks  Coffee Shop
# 3                 Starbucks  Coffee Shop
# 4  Starbucks @ BN Bookstore  Coffee Shop
# 5                 Starbucks  Coffee Shop
# 6                 Starbucks         Café
# 7            CCNY Starbucks    Bike Shop
#
#                                 address  cc      city        country  \
# 0                         4001 Broadway  US  New York  United States
# 1                        301 W 145th St  US  New York  United States
# 2                       700 Exterior St  US     Bronx  United States
# 3                        260 E 161st St  US     Bronx  United States
# 4                         3954 Broadway  US  New York  United States
# 5              CIty College of New York  US  New York  United States
# 6               177 Fort Washington Ave  US  New York  United States
# 7  NAC Plaza / Marshak Science Building  US  New York  United States
#
#                 crossStreet  distance  \
# 0             at W 168th St      1711
# 1          at Bradhurst Ave      1543
# 2                 at Target      1154
# 3             at Morris Ave       785
# 4   Columbia Medical Center      2030
# 5  at North Academic Center      2262
# 6         West 168th Street      1904
# 7                   at CCNY      1753
#
#                                     formattedAddress  \
# 0  [4001 Broadway (at W 168th St), New York, NY 1...
# 1  [301 W 145th St (at Bradhurst Ave), New York, ...
# 2  [700 Exterior St (at Target), Bronx, NY 10451,...
# 3  [260 E 161st St (at Morris Ave), Bronx, NY 104...
# 4  [3954 Broadway (Columbia Medical Center), New ...
# 5  [CIty College of New York (at North Academic C...
# 6  [177 Fort Washington Ave (West 168th Street), ...
# 7  [NAC Plaza / Marshak Science Building (at CCNY...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.84118767, 'lng...  40.841188 -73.939843
# 1  [{'label': 'display', 'lat': 40.82327035, 'lng...  40.823270 -73.942834
# 2  [{'label': 'display', 'lat': 40.81963, 'lng': ...  40.819630 -73.930390
# 3  [{'label': 'display', 'lat': 40.82555649, 'lng...  40.825556 -73.918865
# 4  [{'label': 'display', 'lat': 40.842929, 'lng':...  40.842929 -73.942952
# 5  [{'label': 'display', 'lat': 40.81992301549787...  40.819923 -73.950154
# 6  [{'label': 'display', 'lat': 40.841488, 'lng':...  40.841488 -73.942760
# 7  [{'label': 'display', 'lat': 40.82363288050828...  40.823633 -73.945801
#
#   postalCode state                        id
# 0      10032    NY  4b25a38bf964a520dc7424e3
# 1      10039    NY  4a25743af964a520547e1fe3
# 2      10451    NY  4fc94580d4f24895b4467d5c
# 3      10451    NY  55f96d71498e452a8e98af29
# 4      10032    NY  54636ccb498ec5113126882f
# 5      10031    NY  4d949586cf46224b5fe49794
# 6      10032    NY  5bca2e431ffe97002c40830a
# 7      10032    NY  4c28ecbd360cef3b2a2ebedc

# %% [markdown]
# ###### Map

# %%
# generate map centred around the Yankees Stadium
venues_map = folium.Map(location=[40.82958275, -73.926521184919], zoom_start=14) 

folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Yankees Stadium',
    fill=True,
    color='blue',
    fill_color='blue',
    fill_opacity=0.6
    ).add_to(venues_map)
    
# label sorrounding Starbucks to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
